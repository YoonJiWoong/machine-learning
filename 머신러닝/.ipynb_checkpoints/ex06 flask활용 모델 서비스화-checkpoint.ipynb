# %% [markdown]
# ### 목표
# - 학습된 모델을 서비스화 시키는 도구로 flask를 사용해보자.

# %%
# 이미지를 데이터화할때 사용하기 위해 opencv 설치
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\smhrd\anaconda3\lib\site-packages (4.5.4.60)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\smhrd\anaconda3\lib\site-packages (from opencv-python) (1.20.1)

# %%
# 분석용 서버 구축을 위한 flask 설치
# !pip install flask
# Out:
# Requirement already satisfied: flask in c:\users\smhrd\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\smhrd\anaconda3\lib\site-packages (from flask) (1.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\smhrd\anaconda3\lib\site-packages (from flask) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\smhrd\anaconda3\lib\site-packages (from flask) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\smhrd\anaconda3\lib\site-packages (from flask) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\smhrd\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask) (1.1.1)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
from flask import Flask, render_template, request
import cv2
import io
import numpy as np
import matplotlib.pyplot as plt

app = Flask(__name__)

# 사용자 요청을 받기 위한 라우터 설정
@app.route('/')
def index():
    return render_template('upload.html')

@app.route('/fileUpload', methods=['GET','POST'])
def fileUpload():
    if request.method == 'POST': # 요청이 POST 방식일때
        f = request.files['file'] # 요청 객체에서 file 이름을 가진 데이터를 꺼내오기
        in_memory_file = io.BytesIO() # byre 단위로 파일을 읽기 위한 객체
        f.save(in_memory_file) # byte단위 파일로 저장
        data = np.fromstring(in_memory_file.getvalue(), dtype=np.uint8) # numpy 타입으로 데이터 읽기
        color_image_flag = 1
        img = cv2.imdecode(data,color_image_flag) # opencv 활용해서 이미지 데이터로 변경
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        display(plt.imshow(img_rgb)) # 이미지 그리기
        plt.show() # 이미지 보이기
        
    return "upload"

app.run() # 서버구동
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [11/Dec/2021 09:43:02] "GET / HTTP/1.1" 200 -
# <ipython-input-9-9c981b63b2ba>:20: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   data = np.fromstring(in_memory_file.getvalue(), dtype=np.uint8) # numpy 타입으로 데이터 읽기
# 127.0.0.1 - - [11/Dec/2021 09:43:10] "POST /fileUpload HTTP/1.1" 200 -
